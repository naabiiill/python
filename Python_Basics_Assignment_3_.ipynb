# %% [markdown]
# <a href="https://colab.research.google.com/github/naabiiill/python/blob/main/Python_Basics_Assignment_3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Given list of fruits
fruits = ["apple", "banana", "cherry", "mango"]

# Printing index and fruit name
for index, fruit in enumerate(fruits):
    print(index, fruit)
# Out:
# 0 apple
# 1 banana
# 2 cherry
# 3 mango

# %%
# Lists of students and scores
students = ["Rahim", "Karim", "Ayesha"]
scores = [85, 90, 78]

# Print each student with their score
for student, score in zip(students, scores):
    print(f"{student} scored {score}")
# Out:
# Rahim scored 85
# Karim scored 90
# Ayesha scored 78

# %%
# Tuple of subjects
subjects = ("Math", "Physics", "Chemistry", "English", "Biology")

# Print each subject
for subject in subjects:
    print(subject)
# Out:
# Math
# Physics
# Chemistry
# English
# Biology

# %%
# Given sets
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7}

# Print common elements
print("Common elements:", set1 & set2)

# Print unique elements of set1
print("Unique elements of set1:", set1 - set2)
# Out:
# Common elements: {4, 5}
# Unique elements of set1: {1, 2, 3}

# %%
# Dictionary of marks
marks = {
    "Math": 80,
    "Physics": 75,
    "Chemistry": 85
}

# Print subject number, name, and marks
for index, (subject, mark) in enumerate(marks.items(), start=1):
    print(f"{index} {subject}: {mark}")
# Out:
# 1 Math: 80
# 2 Physics: 75
# 3 Chemistry: 85
